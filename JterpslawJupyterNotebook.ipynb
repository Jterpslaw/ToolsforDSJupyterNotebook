# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Joshua Friedman**
# COO

# %% [markdown]
# *I am interested in data science because it is a fast growing industry. I would like to learn more about it for my career prospects.*

# %% [markdown]
# ### My code will perform a simple mathematical calculation.

# %%
150+235

# %% [markdown]
# 1. test
# 2. Maybe
# 3. I'm not sure
# --- --- ---
# * This works
# * Success?
# * Yes it does!
